# %% [markdown]
# # Escalado
# Conjunto de datos: iris (incluido en sklearn)
# Este conjunto de datos es compacto y perfecto para demostrar técnicas de escalado.

# %%
# Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
iris = load_iris(as_frame=True)
data = iris.data

# %%
# Visualizar las estadísticas iniciales
print("Estadísticas iniciales:")
data.describe()
# Out:
# Estadísticas iniciales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Aplicar MinMaxScaler
minmax_scaler = MinMaxScaler()
data_minmax = pd.DataFrame(minmax_scaler.fit_transform(data), columns=data.columns)

# %%
# Aplicar StandardScaler
standard_scaler = StandardScaler()
data_standard = pd.DataFrame(standard_scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado. Crea gráficas en donde veas correcto.

# %% [markdown]
# ### 1. ¿Qué diferencias encuentras entre las estadísticas originales y las del escalado MinMax?

# %%
print("Estadísticas originales:")
print(data.describe())
print("\nEstadísticas después de MinMaxScaler (valores en [0, 1]):")
print(data_minmax.describe())
# Out:
# Estadísticas originales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Estadísticas después de MinMaxScaler (valores en [0, 1]):
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...

# %% [markdown]
# ### 2. Crea una gráfica de la distribución de la variable 'sepal length (cm)' antes y después del escalado.

# %%
# Distribución de 'sepal length (cm)' antes y después del escalado MinMax
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].hist(data['sepal length (cm)'], bins=20, color='steelblue', edgecolor='black', alpha=0.7)
axes[0].set_title("Antes del escalado")
axes[0].set_xlabel("sepal length (cm)")
axes[0].set_ylabel("Frecuencia")

axes[1].hist(data_minmax['sepal length (cm)'], bins=20, color='coral', edgecolor='black', alpha=0.7)
axes[1].set_title("Después de MinMaxScaler")
axes[1].set_xlabel("sepal length (cm)")
axes[1].set_ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Crea una gráfica de dispersión entre 'sepal length (cm)' y 'sepal width (cm)' con los datos escalados por StandardScaler.

# %%
# Dispersión: sepal length vs sepal width (datos con StandardScaler)
plt.figure(figsize=(8, 6))
plt.scatter(data_standard['sepal length (cm)'], data_standard['sepal width (cm)'], alpha=0.6)
plt.xlabel("sepal length (cm) - escalado")
plt.ylabel("sepal width (cm) - escalado")
plt.title("Dispersión con datos StandardScaler")
plt.show()

# %% [markdown]
# ### 4. ¿Qué técnica de escalado crees que es más adecuada para este conjunto de datos? ¿Por qué?

# %%
print("StandardScaler es más adecuado para iris porque:")
print("- Las características están en unidades (cm) con distintas varianzas.")
print("- Centra en 0 y normaliza por desviación típica, ideal para distancias y modelos lineales.")
print("- MinMax es sensible a outliers; iris es relativamente limpio pero StandardScaler es más robusto.")
# Out:
# StandardScaler es más adecuado para iris porque:
# - Las características están en unidades (cm) con distintas varianzas.
# - Centra en 0 y normaliza por desviación típica, ideal para distancias y modelos lineales.
# - MinMax es sensible a outliers; iris es relativamente limpio pero StandardScaler es más robusto.
